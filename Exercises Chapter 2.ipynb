# %% [markdown]
# # 2.4 Exercises

# %%
## %pip install numpy

import numpy as np

# %%
# %pip install matplotlib

from matplotlib.pyplot import subplots

# %%
# %pip install pandas
import os
os.listdir()

import pandas as pd

# %% [markdown]
# ### Conceptual:
#
# #### 1.
# For each of parts (a) through (d), indicate whether we would generally
# expect the performance of a flexible statistical learning method to be
# better or worse than an inflexible method. Justify your answer.
#
# (a) The sample size n is extremely large, and the number of predictors
# p is small.
#
# <span style="color:blue"> I'd say you want flexible as 'n' is large, and p is small. P being small implies that theres less variables to stretch, so its harder for overfitting to occur. Similarly, more data points implies noise is less significant.</span>
#
# <span style="color:green">A more flexible method would perform better in this case, as we can avoid overfitting the data because of the large sample size.</span>
#
# (b) The number of predictors p is extremely large, and the number
# of observations n is small.
#
# <span style="color:blue"> I would want an inflexible method, as theres a large number (p) of things to be stretched, and a small number of data to keep the predictive variables honest.</span>
#
# <span style="color:green">A less flexible model would perform better in this case, as using a more flexible model would result in overfitting the data to the small sample size.</span>
#
# (c) The relationship between the predictors and response is highly
# non-linear.
# <span style="color:blue"> Barring me knowing the very specific form of the data, Id want a flexible model.</span>
#
# <span style="color:green">A more flexible model would perform better in this case, as less flexible models tend to result in more rigid and almost linear fits which wouldn’t work in the case of our non-linear data.</span>
#
# (d) The variance of the error terms, i.e. $2 = Var("), is extremely
# high.
#
# <span style="color:blue"> If the datas error terms are very loud so to speak, it means the more flexible model might pick up the noise. Id say tentatively that I would want a less flexible model, but I'm less sure about this one.</span>
#
# <span style="color:red">This error term is irreducible and isn’t affected by the flexibility of our model, though we would like to find a flexibility that minimises the bias and variance of
# .</span>

# %% [markdown]
# #### 2.
# Explain whether each scenario is a classification or regression problem,
# and indicate whether we are most interested in inference or prediction.
# Finally, provide n and p.
#
# (a) We collect a set of data on the top 500 firms in the US. For each
# firm we record profit, number of employees, industry and the
# CEO salary. We are interested in understanding which factors
# affect CEO salary.
#
# <span style="color:blue"> This is regression, as CEO salary is numeric and continuous (or we can treat it that way). N = 500, p = 3.</span>
#
# <span style="color:green"> yep </span>
#
# (b) We are considering launching a new product and wish to know
# whether it will be a success or a failure. We collect data on 20
# similar products that were previously launched. For each product
# we have recorded whether it was a success or failure, price
# charged for the product, marketing budget, competition price,
# and ten other variables.
#
# <span style="color:blue"> Classification as its either a success or a failiure (discrete number of outcomes). N = 20. p = 13</span>
#
# <span style="color:green"> yep </span>
#
# (c) We are interested in predicting the % change in the USD/Euro
# exchange rate in relation to the weekly changes in the world
# stock markets. Hence we collect weekly data for all of 2012. For
# each week we record the % change in the USD/Euro, the %
# change in the US market, the % change in the British market,
# and the % change in the German market.
#
# <span style="color:blue"> Regression problem as % change is numeric and continuous. n = 52. p = 3.</span>
#
# <span style="color:green"> yep </span>

# %% [markdown]
# #### 3.
#
# We now revisit the bias-variance decomposition.
#
# (a) Provide a sketch of typical (squared) bias, variance, training error,
# test error, and Bayes (or irreducible) error curves, on a single
# plot, as we go from less flexible statistical learning methods
# towards more flexible approaches. The x-axis should represent
# the amount of flexibility in the method, and the y-axis should
# represent the values for each curve. There should be five curves.
# Make sure to label each one.
#
# (b) Explain why each of the five curves has the shape displayed in
# part (a).

# %% [markdown]
# <img src="images_for_notes/ex2_q3.png" width="600">
#
# <span style="color:green"> Test: The test error will get better until it reaches the "optimal" amount of flexibility for the best prediction of training data with test data, then it will get worse as the training datas random noise will start getting too influential. </span>
#
# <span style="color:green">  Var: "The variance in the prediction increases as the flexibility increases." </span>
#
# <span style="color:green">  Bias^2: The squared bias decreases the more flexible the model (remember bias variance trade off) </span>
#
# <span style="color:green">  Irreducible error: stays the same no matter what </span>
#
# <span style="color:green">  Training error: It starts off decreasing but as the flexibility increases beyond a certain point the model starts overfitting on the noise in the data which results in the curve going below the irreducible error line. </span>

# %% [markdown]
# #### 4.
# You will now think of some real-life applications for statistical learning.
#
# (a) Describe three real-life applications in which classification might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer.
#
# <span style="color:blue"> Predicting which service of airline a person will choose. predictors: age, gender, time spent on comparative website, amount of ads seen, country, destination. Response: Which they will choose. Next might be seeing if someone has cancer, predictors include age, gender, height, weight, whether they present symptoms, whether their family has had the same cancer. Response: whether they have that sort of cancer or not. Predicting which horse will win horse race. Predictors: Age, height, weight, gender, experience of jockey, temperature that day, field conditions. Prediction: Who will win.</span>
#
# (b) Describe three real-life applications in which regression might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer.
#
# <span style="color:blue"> I know this, predicting the amount of time it will take for a delivery to arrive. Predictors: Time ordered, server rating, restaurant, your location, weather, day of the week, size of your order. Prediction: Time in seconds since order.</span>
#
# (c) Describe three real-life applications in which cluster analysis
# might be useful.
#
# <span style="color:red"> Grouping diseases together in classes based on their features. Reccommendation Systems. Giving a user specific media reccs based on their media consumption history. Detecting anomalies in data.
# </span>

# %% [markdown]
# #### 5
# What are the advantages and disadvantages of a very flexible (versus
# a less flexible) approach for regression or classification? Under what
# circumstances might a more flexible approach be preferred to a less
# flexible approach? When might a less flexible approach be preferred?
#
# <span style="color:blue"> Flexible Models are able to bend more to weirder curves, when one isnt sure what the distribution of the response might be, the advantage of a flexible model is it is more able to adapt to this. A less flexible model is less prone to overfitting. For regression, this is the case. For Classification, a more flexible approach corresponds to one with less nearest neighbors. It has the same problems and advantages: Overfitting, and more complex shapes allowed.</span>
#
# <span style="color:red"> Thats right, but also say this: A more flexible method would be preferred in situations where the sample size is sufficiently large and the underlying distribution seems to be non-linear. A less flexible method would be preferred when the sample size is small and the underlying distribution seems to be linear.
# </span>

# %% [markdown]
# #### 6
# Describe the differences between a parametric and a non-parametric
# statistical learning approach. What are the advantages of a parametric
# approach to regression or classification (as opposed to a nonparametric
# approach)? What are its disadvantages?
#
# <span style="color:blue"> Parametric is kinda similar to a less flexible model, and so the advantages and disadvantages are the same. Parametric there are less things to estimate, but you are less well equiped to deal with weird relationships between predictors and response. Also, its easier to understand, and easier to calculate. The opposite is true for non parametric.</span>
#
# <span style="color:red">
# Advantages: Less computationally intensive. Easier to estimate paramters than an entire arbitrary function.
# Disadvantages: If the chosen model is too far from the true then we’ll end up with poor results.
#
# So not quite what youre saying. The less computationally expensive is different to less complicated.
# </span>

# %% [markdown]
# #### 7.
# The table below provides a training data set containing six observations,
# three predictors, and one qualitative response variable.
#
# <img src="images for notes/ex2_q7.png" width="600">
#
# Suppose we wish to use this data set to make a prediction for Y when
# X1 = X2 = X3 = 0 using K-nearest neighbors.
#
# (a) Compute the Euclidean distance between each observation and
# the test point, X1 = X2 = X3 = 0.
#
# <span style="color:blue">Distance to Obs 1 is 3, and is Red.</span>
#
# <span style="color:blue">Distance to Obs 2 is 2, and is Red.</span>
#
# <span style="color:blue">Distance to Obs 3 is root(10), and is Red.</span>
#
# <span style="color:blue">Distance to Obs 4 is root(5), and is Green.</span>
#
# <span style="color:blue">Distance to Obs 5 is root(2), and is Green.</span>
#
# <span style="color:blue">Distance to Obs 6 is root(3), and is Red.</span>
#
#
# <span style="color:blue">Ergo ranking is Obs5 (root2) Green, Obs6 (root3) Red, Obs2 (2) Red,  Obs4 (root5) Green, Obs1(3) Red, Obs3(root10) Red</span>
#
# (b) What is our prediction with K = 1? Why?
#
# <span style="color:blue">Its Green, as its closest neighbor is Obs5 at distance root2, and that obs is green.</span>
#
# (c) What is our prediction with K = 3? Why?
#
# <span style="color:blue">Its Red, as 2 of the 3 closest neighbors are red (obs6 and obs2 are red, while obs5 is green).</span>
#
# (d) If the Bayes decision boundary in this problem is highly nonlinear,
# then would we expect the best value for K to be large or
# small? Why?
#
# <span style="color:blue"> Id use a smaller K as it allows for weirder shapes.</span>
#
# <span style="color:green">  Meowth thats right </span>

# %% [markdown]
# ## Applied Section
#
# #### 8.
# This exercise relates to the College data set, which can be found in
# the file College.csv on the book website. It contains a number of
# variables for 777 different universities and colleges in the US. The
# variables are
#
# Private : Public/private indicator
# • Apps : Number of applications received
# • Accept : Number of applicants accepted
# • Enroll : Number of new students enrolled
# • Top10perc : New students from top 10 % of high school class
# • Top25perc : New students from top 25 % of high school class
# • F.Undergrad : Number of full-time undergraduates
# • P.Undergrad : Number of part-time undergraduates
# • Outstate : Out-of-state tuition
# • Room.Board : Room and board costs
# • Books : Estimated book costs
# • Personal : Estimated personal spending
# • PhD : Percent of faculty with Ph.D.s
# • Terminal : Percent of faculty with terminal degree
# • S.F.Ratio : Student/faculty ratio
# • perc.alumni : Percent of alumni who donate
# • Expend : Instructional expenditure per student
# • Grad.Rate : Graduation rate
#
# Before reading the data into Python, it can be viewed in Excel or a
# text editor.
#
# (a) Use the pd.read_csv() function to read the data into Python. Call
# the loaded data college. Make sure that you have the directory
# set to the correct location for the data.

# %%
college = pd.read_csv('datasets/College.csv', sep=',')

college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# Look at the data used in the notebook by creating and running
# a new cell with just the code college in it. You should notice
# that the first column is just the name of each university in a
# column named something like Unnamed: 0. We don’t really want
# pandas to treat this as data. However, it may be handy to have
# these names for later. Try the following commands and similarly
# look at the resulting data frames:

# %%
college2 = pd.read_csv('datasets/College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
axis=1)
college3 = college3.set_index('College')

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# This has used the first column in the file as an index for the
# data frame. This means that pandas has given each row a name
# corresponding to the appropriate university. Now you should see
# that the first data column is Private. Note that the names of
# the colleges appear on the left of the table. We also introduced
# a new python object above: a dictionary, which is specified by (key, value) pairs. Keep your modified version of the data with
# the following:

# %%
college = college3

# %%
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# (c) Use the describe() method of to produce a numerical summary
# of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# Answer sheet gave me this:
college2.describe?
# Out:
# Signature: college2.describe(percentiles=None, include=None, exclude=None) -> 'Self'
# Docstring:
# Generate descriptive statistics.
#
# Descriptive statistics include those that summarize the central
# tendency, dispersion and shape of a
# dataset's distribution, excluding ``NaN`` values.
#
# Analyzes both numeric and object series, as well
# as ``DataFrame`` column sets of mixed data types. The output
# will vary depending on what is provided. Refer to the notes
# below for more detail.
#
# Parameters
# ----------
# percentiles : list-like of numbers, optional
#     The percentiles to include in the output. All should
#     fall between 0 and 1. The default, ``None``, will automatically
#     return the 25th, 50th, and 75th percentiles.
# include : 'all', list-like of dtypes or None (default), optional
#     A white list of data types to include in the result. Ignored
#     for ``Series``. Here are the options:
#
# ...

# %%
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate'],
#       dtype='str')

# %%
college2.describe(include='str')
# Out:
#        Private
# count      777
# unique       2
# top        Yes
# freq       565

# %% [markdown]
# (d) Use the pd.plotting.scatter_matrix() function to produce a
# scatterplot matrix of the first columns [Top10perc, Apps, Enroll].
# Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]]);

# %% [markdown]
# (e) Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private.

# %%
## pd.plotting.boxplot(college[["Outstate"]], by=college[['Private']])

bp = college[["Outstate", "Private"]].boxplot(by='Private')
bp
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='[Private]'>

# %% [markdown]
# (f) Create a new qualitative variable, called Elite, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.

# %%
# Cool way to see (and sort really) table sorted by specific column. You can make it ascending or descending. 
# college.sort_values(by='Top10perc', ascending=False)

# %%
college.sort_values?
# Out:
# Signature:
# college.sort_values(
#     by: 'IndexLabel',
#     *,
#     axis: 'Axis' = 0,
#     ascending: 'bool | list[bool] | tuple[bool, ...]' = True,
#     inplace: 'bool' = False,
#     kind: 'SortKind' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc | None' = None,
# ) -> 'DataFrame | None'
# Docstring:
# Sort by the values along either axis.
#
# Parameters
# ----------
# by : str or list of str
#     Name or list of names to sort by.
#
#     - if `axis` is 0 or `'index'` then `by` may contain index
#       levels and/or column labels.
#     - if `axis` is 1 or `'columns'` then `by` may contain column
#       levels and/or index labels.
# axis : "{0 or 'index', 1 or 'columns'}", default 0
#      Axis to be sorted.
# ascending : bool or list of bool, default True
#      Sort ascending vs. descending. Specify list for multiple sort
#      orders.  If this is a list of bools, must match the length of
#      the by.
# ...

# %%
pd.cut(college['Top10perc']/100,
[0,0.5,1],
labels=['No', 'Yes'])
# Out:
# College
# Abilene Christian University       No
# Adelphi University                 No
# Adrian College                     No
# Agnes Scott College               Yes
# Alaska Pacific University          No
#                                  ...
# Worcester State College            No
# Xavier University                  No
# Xavier University of Louisiana     No
# Yale University                   Yes
# York College of Pennsylvania       No
# Name: Top10perc, Length: 777, dtype: category
# Categories (2, str): ['No' < 'Yes']

# %%
college['Elite'] = pd.cut(college['Top10perc']/100, 
                     [0,0.5,1],
                     labels=['No', 'Yes'])

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# (g)
# Use the plot.hist() method of college to produce some histograms
# with differing numbers of bins for a few of the quantitative
# variables. The command plt.subplots(2, 2) may be useful:
# it will divide the plot window into four regions so that four
# plots can be made simultaneously. By changing the arguments
# you can divide the screen up in other combinations.

# %%
#college.hist('Apps', color='red', bins=12, ax=ax);

fig , axes = subplots(nrows=2,
ncols=3,
figsize=(15, 5))

"""
import matplotlib.pyplot as plt
import numpy as np

data1 = np.random.randn(100)
data2 = np.random.rand(100)

# First subplot
plt.subplot(2, 1, 1)
plt.hist(data1, bins=15, color='blue')
plt.title('Normal Distribution')
"""

print("true")
# Out:
# true

# %%
#axes[0,1].plot(x, y, 'o')
#axes[1,2].scatter(x, y, marker='+')
#fig

#fig.subplot(0,0)
#subplots.hist(college[['Apps']], color=red, bins=20);
#college.hist('Accept', color='red', bins=20);

college.hist('Apps', color='red', bins=12);

# %%
# Ok cool, lets add this to the set of 6 plots:
#axes[0,1].plot(college.hist('Accept', color='red', bins=20);)
#axes[1,2].scatter(x, y, marker='+')
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 5))

college.hist(column='Apps', color='red', bins=12, ax=axes[0, 0])

# 3. (Optional) Title the specific subplot to keep track
axes[0, 0].set_title("Histogram of Apps")

# 4. Display
plt.tight_layout() # Prevents labels from overlapping
plt.show()

### Mesco here: Ok so the ax command tells you where this is being plotted? This is progress I suppose, I will probably remember that, and it will come
# back later faster if not.

# %% [markdown]
# (h) Continue exploring the data, and provide a brief summary of
# what you discover.

# %%
# Ok lets go onto that website and see if we can add something cool

# Lets do a simple x vs y sorta thing, but we need to relook at the data and choose

college.head()

# Scatterplots come to mind?
# Lets do a scatterplot of Books vs Top25perc.
# Ah perfect: "Scatterplot with histograms":
"""
fig, axs = plt.subplot_mosaic([['histx', '.'],
                               ['scatter', 'histy']],
                              figsize=(6, 6),
                              width_ratios=(4, 1), height_ratios=(1, 4),
                              layout='constrained')
scatter_hist(x, y, axs['scatter'], axs['histx'], axs['histy'])
"""

# Ahhh wait wait, this thing is making a NEW subplot...
#~WEll we can try it anyways

fig2, axs2 = plt.subplot_mosaic([['histx', '.'],
                               ['scatter', 'histy']],
                              figsize=(6, 6),
                              width_ratios=(4, 1), height_ratios=(1, 4),
                              layout='constrained')
scatter_hist(college[["Books"]], college[["Top25perc"]], axs['histx'], axs['histy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 27
#      19 # Ahhh wait wait, this thing is making a NEW subplot...
#      20 #~WEll we can try it anyways
#      22 fig2, axs2 = plt.subplot_mosaic([['histx', '.'],
#      23                                ['scatter', 'histy']],
#      24                               figsize=(6, 6),
#      25                               width_ratios=(4, 1), height_ratios=(1, 4),
#      26                               layout='constrained')
# ---> 27 scatter_hist(college[["Books"]], college[["Top25perc"]], axs['histx'], axs['histy'])
#
# NameError: name 'scatter_hist' is not defined

# %%
college.scatter("Books", "Top25Perc")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27192\3097369294.py in ?()
# ----> 1 college.scatter("Books", "Top25Perc")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
axes[1,2].scatter(college[["Books"]], college[["Top25Perc"]], marker='+')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 axes[1,2].scatter(college[["Books"]], college[["Top25Perc"]], marker='+')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...

# %%
import matplotlib.pyplot as plt

# 1. Create the grid (2 rows, 3 columns)
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 5))

# 2. Draw the histogram, explicitly targeting the first box (row 0, col 0)
college.hist(column='Apps', color='red', bins=12, ax=axes[0, 0])

# 3. (Optional) Title the specific subplot to keep track
axes[0, 0].set_title("Histogram of Apps")

# 4. Display
plt.tight_layout() # Prevents labels from overlapping
plt.show()

# %%
# jesus what a battlefield. The trick is this: college.PLOT.scatter
# You cant just call college.scatter, you have to subcall plot first

college.plot.scatter(x='Books', y='Top25perc', ax=axes[1,1], color='purple')

axes[1, 1].set_title("Books vs Top 25%")

#Man I dont like using Gemini cause Im worried I wont *actually* learn, but I spent a good 30 mins wrestling 
# and I have time to do (do I have time?) projects later
plt.tight_layout() # Prevents labels from overlapping
##plt.show()

fig

# %%
## Ok now for some answers:

college.hist(figsize=(15,15), bins=20);

# %% [markdown]
# ## Question 9:
#
# This exercise involves the Auto data set studied in the lab. Make sure
# that the missing values have been removed from the data.

# %%
# Ok so we need to find the Auto dataset. How do we do that? Lets look at our previous import?
Auto = pd.read_csv('datasets/Auto.data.txt', na_values=['?'], sep='\s+')
Auto['horsepower'].sum()
# Out:
# np.float64(40952.0)

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative?

# %%
Auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0  3504.0          12.0    70
# 1  15.0          8         350.0       165.0  3693.0          11.5    70
# 2  18.0          8         318.0       150.0  3436.0          11.0    70
# 3  16.0          8         304.0       150.0  3433.0          12.0    70
# 4  17.0          8         302.0       140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# - MPG: Quant
# - Cylinders: Qualit
# - Displacement: Quant
# - Horsepower: Quant
# - Weight: Quant
# - Acceleration: Quant
# - Year: Qualit (could maybbbeee be quant)
# - Origin: Qualit
# - Name: Qualit

# %%
Auto['displacement'].value_counts()
# Out:
# displacement
# 97.0     21
# 350.0    18
# 98.0     18
# 318.0    17
# 250.0    17
#          ..
# 81.0      1
# 100.0     1
# 145.0     1
# 181.0     1
# 144.0     1
# Name: count, Length: 82, dtype: int64

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can answer
# this using the min() and max() methods in numpy.

# %%
# Well we can write a cool function for this probably. 
#The problem with pandas is idk how things work, so I'm just parroting. Parroting will have to do for now

# %%
for series_name, series in Auto.items():
    print(series_name)
    print(series)
# Out:
# mpg
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 392    27.0
# 393    44.0
# 394    32.0
# 395    28.0
# 396    31.0
# Name: mpg, Length: 397, dtype: float64
# cylinders
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 392    4
# 393    4
# 394    4
# 395    4
# 396    4
# Name: cylinders, Length: 397, dtype: int64
# displacement
# 0      307.0
# 1      350.0
# 2      318.0
# 3      304.0
# 4      302.0
#        ...
# 392    140.0
# 393     97.0
# 394    135.0
# 395    120.0
# 396    119.0
# Name: displacement, Length: 397, dtype: float64
# horsepower
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 392     86.0
# 393     52.0
# 394     84.0
# 395     79.0
# 396     82.0
# Name: horsepower, Length: 397, dtype: float64
# weight
# 0      3504.0
# 1      3693.0
# 2      3436.0
# 3      3433.0
# 4      3449.0
#         ...
# 392    2790.0
# 393    2130.0
# 394    2295.0
# 395    2625.0
# ...

# %%
test_14 = 'mpg'

Auto[[test_14]].min()
# Out:
# mpg    9.0
# dtype: float64

# %%
for series_name, series in Auto.items():
    print(series_name)
# Out:
# mpg
# cylinders
# displacement
# horsepower
# weight
# acceleration
# year
# origin
# name

# %%
test_16 = [0]*Auto.shape[1]

test_15 = Auto.columns.values.tolist()

#for i in range(Auto.shape[1]):
for i in range(8):
    test_16[i] = Auto[test_15[i]].min().tolist()
test_16
# Out:
# [9.0, 3, 68.0, 46.0, 1613.0, 8.0, 70, 1, 0]

# %%
test_16 = [0]*Auto.shape[1]
test_17 = [0]*Auto.shape[1]

test_15 = Auto.columns.values.tolist()

#for i in range(Auto.shape[1]):
for i in range(9):
    if type(Auto[test_15[i]].min()) != str:
        test_16[i] = Auto[test_15[i]].min().tolist()
        test_17[i] = Auto[test_15[i]].max().tolist()
    elif type(Auto[test_15[i]].min()) == str:
        test_16[i] = Auto[test_15[i]].min()
        test_17[i] = Auto[test_15[i]].max()
    else:
        print('error, datatype not string nor integer64')
        break

#test_16

for i in range(len(test_16)):
    if type(test_16[i]) != str:
        print(test_15[i])
        print('minimum :' + str(test_16[i]))
        print('maximum :' + str(test_17[i]))
        print('range :' + str(test_17[i]-test_16[i]))
        print('----------------')
    else:
        print('Error, no range with qualitative data')
        print('----------------')
# Out:
# mpg
# minimum :9.0
# maximum :46.6
# range :37.6
# ----------------
# cylinders
# minimum :3
# maximum :8
# range :5
# ----------------
# displacement
# minimum :68.0
# maximum :455.0
# range :387.0
# ----------------
# horsepower
# minimum :46.0
# maximum :230.0
# range :184.0
# ----------------
# weight
# minimum :1613.0
# maximum :5140.0
# range :3527.0
# ----------------
# acceleration
# minimum :8.0
# maximum :24.8
# range :16.8
# ----------------
# year
# minimum :70
# maximum :82
# range :12
# ----------------
# origin
# minimum :1
# maximum :3
# range :2
# ----------------
# Error, no range with qualitative data
# ----------------

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative .max()
# predictor?

# %%
# Hehe, now we can reuse our code
# We setup empty lists (yes lists) to put the data into
test_18_mean = [0]*Auto.shape[1]
test_19_stddev = [0]*Auto.shape[1]

for i in range(Auto.shape[1]):
    if type(Auto[test_15[i]].min()) != str:
        test_18_mean[i] = Auto[test_15[i]].mean().tolist()
        test_19_stddev[i] = Auto[test_15[i]].std().tolist()
    elif type(Auto[test_15[i]].min()) == str:
        test_18_mean[i] = Auto[test_15[i]].mode()
        test_19_stddev[i] = 'Qualitative, no Std.Dev'
    else:
        print('error, datatype not string nor integer64')
        break

for i in range(len(test_18_mean)):
    if type(Auto[test_15[i]].min()) != str:
        print('Mean :' + str(test_18_mean[i]))
        print('Standard deviation :' + str(test_19_stddev[i]))
        print('----------------')
    else:
        print('Mode :' + str(test_18_mean[i]))
        print('Standard deviation :' + str(test_19_stddev[i]))
        print('----------------')
# Out:
# Mean :23.51586901763224
# Standard deviation :7.825803928946563
# ----------------
# Mean :5.458438287153652
# Standard deviation :1.7015769807918462
# ----------------
# Mean :193.53274559193954
# Standard deviation :104.37958329992955
# ----------------
# Mean :104.46938775510205
# Standard deviation :38.49115993282849
# ----------------
# Mean :2970.2619647355164
# Standard deviation :847.9041194897246
# ----------------
# Mean :15.55566750629723
# Standard deviation :2.749995292976151
# ----------------
# Mean :75.99496221662469
# Standard deviation :3.690004901461682
# ----------------
# Mean :1.5743073047858942
# Standard deviation :0.8025494957970388
# ----------------
# Mode :0    ford pinto
# Name: name, dtype: str
# Standard deviation :Qualitative, no Std.Dev
# ----------------

# %% [markdown]
# (c) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
Auto.iloc[9:85, :]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 9   15.0          8         390.0       190.0  3850.0           8.5    70
# 10  15.0          8         383.0       170.0  3563.0          10.0    70
# 11  14.0          8         340.0       160.0  3609.0           8.0    70
# 12  15.0          8         400.0       150.0  3761.0           9.5    70
# 13  14.0          8         455.0       225.0  3086.0          10.0    70
# ..   ...        ...           ...         ...     ...           ...   ...
# 80  22.0          4         122.0        86.0  2395.0          16.0    72
# 81  28.0          4          97.0        92.0  2288.0          17.0    72
# 82  23.0          4         120.0        97.0  2506.0          14.5    72
# 83  28.0          4          98.0        80.0  2164.0          15.0    72
# 84  27.0          4          97.0        88.0  2100.0          16.5    72
#
#     origin                         name
# ...

# %%
Auto.shape
# Out:
# (397, 9)

# %%
# This is Stack exchange idea "As @jezrael pointed our, you can also just negate all three:"
# Lets try it

#df[((df.Name != 'jhon') &( df.Age != 15) & (df.Grade != 'A'))]
#Out[477]: 
#   Name  Age Grade
#1  Anna   19     B
#2  Paul   25     D


Auto_remove_10_to_85 = Auto[((Auto.index<9) | (Auto.index>85))]

# %%
Auto_remove_10_to_85 = Auto[((Auto.index<11) | (Auto.index>85))]

test_16 = [0]*Auto_remove_10_to_85.shape[1]
test_17 = [0]*Auto_remove_10_to_85.shape[1]

test_15 = Auto_remove_10_to_85.columns.values.tolist()

#for i in range(Auto.shape[1]):
for i in range(9):
    if type(Auto_remove_10_to_85[test_15[i]].min()) != str:
        test_16[i] = Auto_remove_10_to_85[test_15[i]].min().tolist()
        test_17[i] = Auto_remove_10_to_85[test_15[i]].max().tolist()
    elif type(Auto_remove_10_to_85[test_15[i]].min()) == str:
        test_16[i] = Auto_remove_10_to_85[test_15[i]].min()
        test_17[i] = Auto_remove_10_to_85[test_15[i]].max()
    else:
        print('error, datatype not string nor integer64')
        break

#test_16

for i in range(len(test_16)):
    if type(test_16[i]) != str:
        print(test_15[i])
        print('minimum :' + str(test_16[i]))
        print('maximum :' + str(test_17[i]))
        print('range :' + str(test_17[i]-test_16[i]))
        print('----------------')
    else:
        print('Error, no range with qualitative data')
        print('----------------')
# Out:
# mpg
# minimum :11.0
# maximum :46.6
# range :35.6
# ----------------
# cylinders
# minimum :3
# maximum :8
# range :5
# ----------------
# displacement
# minimum :68.0
# maximum :455.0
# range :387.0
# ----------------
# horsepower
# minimum :46.0
# maximum :230.0
# range :184.0
# ----------------
# weight
# minimum :1649.0
# maximum :4997.0
# range :3348.0
# ----------------
# acceleration
# minimum :8.5
# maximum :24.8
# range :16.3
# ----------------
# year
# minimum :70
# maximum :82
# range :12
# ----------------
# origin
# minimum :1
# maximum :3
# range :2
# ----------------
# Error, no range with qualitative data
# ----------------

# %%
Auto.index
# Out:
# RangeIndex(start=0, stop=397, step=1)

# %%
Auto.loc[Auto['mpg']>=9]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0  3504.0          12.0    70
# 1    15.0          8         350.0       165.0  3693.0          11.5    70
# 2    18.0          8         318.0       150.0  3436.0          11.0    70
# 3    16.0          8         304.0       150.0  3433.0          12.0    70
# 4    17.0          8         302.0       140.0  3449.0          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0  2790.0          15.6    82
# 393  44.0          4          97.0        52.0  2130.0          24.6    82
# 394  32.0          4         135.0        84.0  2295.0          11.6    82
# 395  28.0          4         120.0        79.0  2625.0          18.6    82
# 396  31.0          4         119.0        82.0  2720.0          19.4    82
#
#      origin                       name
# ...

# %%
# lets look at their solution:
Auto.iloc[10:85,].index
# Out:
# RangeIndex(start=10, stop=85, step=1)

# %%
Auto_dropped = Auto.drop(index=Auto.iloc[10:85].index)

Auto_dropped.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 322 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           322 non-null    float64
#  1   cylinders     322 non-null    int64
#  2   displacement  322 non-null    float64
#  3   horsepower    318 non-null    float64
#  4   weight        322 non-null    float64
#  5   acceleration  322 non-null    float64
#  6   year          322 non-null    int64
#  7   origin        322 non-null    int64
#  8   name          322 non-null    str
# dtypes: float64(5), int64(3), str(1)
# memory usage: 25.2 KB

# %%
Auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  397.000000  397.000000    397.000000  392.000000   397.000000
# mean    23.515869    5.458438    193.532746  104.469388  2970.261965
# std      7.825804    1.701577    104.379583   38.491160   847.904119
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.000000   75.000000  2223.000000
# 50%     23.000000    4.000000    146.000000   93.500000  2800.000000
# 75%     29.000000    8.000000    262.000000  126.000000  3609.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    397.000000  397.000000  397.000000
# mean      15.555668   75.994962    1.574307
# std        2.749995    3.690005    0.802549
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
Auto_dropped.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  322.000000  322.000000    322.000000  318.000000   322.000000
# mean    24.409317    5.378882    187.680124  101.235849  2936.807453
# std      7.913357    1.657398    100.120925   36.185088   810.987533
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    100.250000   75.000000  2216.000000
# 50%     23.900000    4.000000    145.500000   90.500000  2797.500000
# 75%     30.650000    6.000000    250.000000  115.000000  3516.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    322.000000  322.000000  322.000000
# mean      15.700621   77.130435    1.596273
# std        2.706436    3.131849    0.815572
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %%
#28 falls between 10th and 85th observaations. 
#Ergo, unless Im missing a reordering of the order of observations, I think I got this one right in a different way

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your findings.

# %%
pd.plotting.scatter_matrix(Auto)
plt.show()

# %% [markdown]
# (e) answer:
#
# <span style="color:blue"> Comment: Its rather small, but we can see some interesting
# relationships. The histogram distributions are varied, one is Gausian, one is Gamma,
# some of the others look odd. The Scatterplots have some linear relationships, some clearly non linear,
# some iwht more and less variance, and with the qualitative ones there are differences too.
# Some seem basically unrelated, like acceleration and year.</span>

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.
#
# <span style="color:blue"> For mpg, we look at the top row and go one by one:</span>
# - <span style="color:blue"> MPG obviously predicts mpg perfectly, but this histogram suggests a gamma distribution. </span>
# - <span style="color:blue"> Cylinders scatterplot suggers that higher values of cylinders imply lower mpg </span>
# - <span style="color:blue"> Displacement scatterplot implies a non linear negative correlation </span>
# - <span style="color:blue"> Horsepower scatterplot implies a non linear negative correlation </span>
# - <span style="color:blue"> Weight scatterplot also implies a non linear negative correlation </span>
# - <span style="color:blue"> Acceleration scatterplot is a bit tricky to tell, but there is some positive correlation happening. Its as if the variance increases with higher acceleration </span>
# - <span style="color:blue">Year scatterplot implies a linear, high variance, positive correlation </span>
#
#
# ### 10.
# This exercise involves the Boston housing data set.
#
# (a) To begin, load in the Boston data set, which is part of the ISLP library
#
# <span style="color:blue"> Well I will download it manually, but maybe next time I should try
# from ISLP import load_data
# Boston = load_data('Boston')
# Boston.columns
# </span>

# %%
Boston = pd.read_csv('datasets/Boston.csv', na_values=['?'], sep=',')
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# (b) How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
Boston.shape
# Out:
# (506, 14)

# %% [markdown]
# <span style="color:blue"> According to Boston.shape, there are 506 rows, and 14 columns.
# My guess as to what the rows represent is neighborhoods in Boston, and the columns represent different aspects of the neighborhood (such as tax rate, distance from the centre, average age (or age of neighbor hood?) Crime rate. Idk what black could be, or lstat or medv.
# </span>

# %%
Boston.info
# Out:
# <bound method DataFrame.info of         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# Taken from anser sheets: ( https://mohamed-badry.github.io/islp-solutions/Exercises_ch02.html )
#
# A data set containing housing values in 506 suburbs of Boston.
#
#     crim: per capita crime rate by town.
#
#     zn: proportion of residential land zoned for lots over 25,000 sq.ft.
#
#     indus: proportion of non-retail business acres per town.
#
#     chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
#     nox: nitrogen oxides concentration (parts per 10 million).
#
#     rm: average number of rooms per dwelling.
#
#     age: proportion of owner-occupied units built prior to 1940.
#
#     dis: weighted mean of distances to five Boston employment centres.
#
#     rad: index of accessibility to radial highways.
#
#     tax: full-value property-tax rate per $10,000.
#
#     ptratio: pupil-teacher ratio by town.
#
#     lstat: lower status of the population (percent).
#
#     medv: median value of owner-occupied homes in $1000s.

# %% [markdown]
# (c) Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your findings.

# %%
# keyword might be "Some" here. The previous scatterplot thingy I did had ALL the pairs, and was really hard to see anything.
pd.plotting.scatter_matrix(Boston[["crim", "age", "dis", "lstat", "nox", "indus", "ptratio"]], figsize=(18,18))
plt.show()

# %%
# Lets describe some of the findings:
# Well reading ahead, the response we will be using is crim (crime rate). Thus, we focus on that. The distribution is very skewed to one side, 
# perhaps it would serve us to see the histogram with more bins:
fig , ax = subplots(figsize=(10, 4))
plt.axvline(Boston['crim'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(Boston['crim'].median(), color='b', linestyle='dashed', linewidth=1)
Boston.hist('crim', color='red', bins=30, ax=ax);
# Interesting.
# The crime in most suburbs is near 0, but once you get above that threshold the distribution gets way flatter.

# %%
# Lets try and upgrade this with a label to the lines
fig , ax = subplots(figsize=(8, 4))
plt.axvline(Boston['crim'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(Boston['crim'].median(), color='b', linestyle='dashed', linewidth=1)
Boston.hist('crim', color='red', bins=30, ax=ax, label=Boston_bar_labels);
# Interesting.
# The crime in most suburbs is near 0, but once you get above that threshold the distribution gets way flatter.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 5
#       3 plt.axvline(Boston['crim'].mean(), color='k', linestyle='dashed', linewidth=1)
#       4 plt.axvline(Boston['crim'].median(), color='b', linestyle='dashed', linewidth=1)
# ----> 5 Boston.hist('crim', color='red', bins=30, ax=ax, label=Boston_bar_labels);
#       6 # Interesting.
#       7 # The crime in most suburbs is near 0, but once you get above that threshold the distribution gets way flatter.
#
# NameError: name 'Boston_bar_labels' is not defined

# %% [markdown]
# (d) Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %%
pd.plotting.scatter_matrix(Boston[['crim', 'zn']])
plt.show()

# %%
pd.plotting.scatter_matrix(Boston, figsize=(18,18));

# %% [markdown]
# # lets look at the asosiaction with per capita crime:
#  - Crime is very skewed, we discussed distribution earlier.
# - zn: idk what this actually means, but when this value is high, theres very little crime, when its low theres a high chance of high crim.
#     - indus: one specific value of indus is associated with higher crime, like a really crazy Gaussian distribution
# -- Charles River dummy variable (= 1 if tract bounds river; 0 otherwise): Areas near the river are less likely to have high crim.
# -- nox: positive correlation. id say strong positive correlation.
# -- rm: weird relationship, but Id say weak negative correlation.
# -- age: areas that are older have higher crime rates. looks non linear, but this is just kinda the nature of crim. Id want to look at crim^2 as a predictor
# -- dis: negative correlation
# -- Rad: Positively correlated, surprisingly. Maybe it shouldnt be, areas that are very far out with huge land dont need railways? Or the index could be inverted, where 1 is very low access.
# -- tax: Positively correlated, but the relationship is just weird
# -- pratio: Pupil teacher ratio: positively correlated, more pupils per teacher implies more crime, but why is it all near one value? I wouldnt expect to see this.
# -- black: Not correlated. Im surprised, Id think it would be as here its a direct comparison.
# -- lstat: Not correlated (I dont thin? Maybe positively?)
# -- medv: negatively correlated, highly non linear.

# %% [markdown]
# (e)
# Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.

# %%
# Well this would be ez pz in SQL:
# Hang on, which col decides suburb name? Via what are we indexing? How do we identify a specific suburb?
Boston.head()
# Looking at the names of the columns (and their previous definitions), there is no column which identifies it, so we just need to see via its index.

# Lets start with crim rates.
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# These neighborhoods (indexed)
Boston.loc[Boston['crim']>=(Boston['crim'].mean()*10)]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666
#
#      ptratio   black  lstat  medv
# 380     20.2  396.90  17.21  10.4
# 398     20.2  396.90  30.59   5.0
# 404     20.2  329.46  27.38   8.5
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0
# 418     20.2   16.45  20.62   8.8
# 427     20.2   18.82  14.52  10.9

# %%
Boston.loc[Boston['tax']>=(Boston['tax'].mean()*1.3)]
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 356  8.98296  0.0  18.10     1  0.770  6.212  97.4  2.1222   24  666     20.2
# 357  3.84970  0.0  18.10     1  0.770  6.395  91.0  2.5052   24  666     20.2
# 358  5.20177  0.0  18.10     1  0.770  6.127  83.4  2.7227   24  666     20.2
# 359  4.26131  0.0  18.10     0  0.770  6.112  81.3  2.5091   24  666     20.2
# 360  4.54192  0.0  18.10     0  0.770  6.398  88.0  2.5182   24  666     20.2
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 488  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4  711     20.1
# 489  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4  711     20.1
# 490  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 491  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711     20.1
# 492  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711     20.1
#
#       black  lstat  medv
# ...

# %%
Boston.loc[Boston['tax']>=(Boston['tax'].mean()*1.65)]
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 488  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4  711     20.1
# 489  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4  711     20.1
# 490  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 491  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711     20.1
# 492  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711     20.1
#
#       black  lstat  medv
# 488  395.09  18.06  15.2
# 489  344.05  23.97   7.0
# 490  318.43  29.68   8.1
# 491  390.11  18.07  13.6
# 492  396.90  13.35  20.1

# %%
# Ok but we want to return it in descending tax order
Boston['tax'].value_counts()
# Out:
# tax
# 666    132
# 307     40
# 403     30
# 437     15
# 304     14
#       ...
# 241      1
# 422      1
# 351      1
# 280      1
# 187      1
# Name: count, Length: 66, dtype: int64

# %%
#Ok so whats our plan here.
# Lets get the values first. THEN we apply some logic to it.
type(Boston['tax'].value_counts())
# Out:
# pandas.Series

# %%
Boston_tax_groupby = Boston['tax'].value_counts()

Boston_tax_groupby
# Out:
# tax
# 666    132
# 307     40
# 403     30
# 437     15
# 304     14
#       ...
# 241      1
# 422      1
# 351      1
# 280      1
# 187      1
# Name: count, Length: 66, dtype: int64

# %%
type(Boston_tax_groupby)
# Out:
# pandas.Series

# %%
# We found something! https://stackoverflow.com/questions/26097916/convert-pandas-series-to-dataframe
Boston_tax_groupby = Boston['tax'].value_counts()

df1_tax_sort = pd.DataFrame(data=Boston_tax_groupby.index, columns=['tax'])
df2_tax_sort = pd.DataFrame(data=Boston_tax_groupby.values, columns=['counts'])

df_tax_sort = pd.merge(df1_tax_sort, df2_tax_sort, left_index=True, right_index=True)

df_tax_sort.sort_values(by = ["tax"], ascending = False)

# Maybe the actual solution would be to sort by tax first, then find counts. But im unsure this would work... well whatever.
# Back to question (e), we see that we missed the point of this question lmao.
# We needed to find the tax rates which are associated with high crime rates, not the ones associated with... high tax rates xddd
# 
# Nevermind, this IS the question being asked. 5 of them have the highest tax rates.
# Out:
#     tax  counts
# 29  711       5
# 0   666     132
# 53  469       1
# 3   437      15
# 13  432       9
# ..  ...     ...
# 25  216       5
# 59  198       1
# 15  193       8
# 22  188       7
# 65  187       1
#
# [66 rows x 2 columns]

# %%
Boston.sort_values(by = ["crim", "tax"], ascending = [False, False]).head(10)
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666
# 413  28.6558  0.0   18.1     0  0.597  5.155  100.0  1.5894   24  666
# 417  25.9406  0.0   18.1     0  0.679  5.304   89.1  1.6475   24  666
#
#      ptratio   black  lstat  medv
# 380     20.2  396.90  17.21  10.4
# 418     20.2   16.45  20.62   8.8
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# ...

# %%
#
Boston_ptratio_groupby = Boston['ptratio'].value_counts()

df1_ptratio_sort = pd.DataFrame(data=Boston_ptratio_groupby.index, columns=['ptratio'])
df2_ptratio_sort = pd.DataFrame(data=Boston_ptratio_groupby.values, columns=['counts'])

df_ptratio_sort = pd.merge(df1_ptratio_sort, df2_ptratio_sort, left_index=True, right_index=True)

df_ptratio_sort.sort_values(by = ["ptratio"], ascending = False).head(7)
# Out:
#     ptratio  counts
# 39     22.0       2
# 10     21.2      15
# 40     21.1       1
# 2      21.0      27
# 14     20.9      11
# 0      20.2     140
# 24     20.1       5

# %%
df_ptratio_sort.sort_values(by = ["ptratio"], ascending = False).tail()
# Out:
#     ptratio  counts
# 1      14.7      34
# 43     14.4       1
# 44     13.6       1
# 12     13.0      12
# 34     12.6       3

# %% [markdown]
# Comment on the range of each predictor.

# %%
Boston.describe(include='all').loc[['mean','std', 'min', 'max']]
# Out:
#            crim          zn      indus      chas       nox        rm  \
# mean   3.613524   11.363636  11.136779  0.069170  0.554695  6.284634
# std    8.601545   23.322453   6.860353  0.253994  0.115878  0.702617
# min    0.006320    0.000000   0.460000  0.000000  0.385000  3.561000
# max   88.976200  100.000000  27.740000  1.000000  0.871000  8.780000
#
#              age        dis        rad         tax    ptratio       black  \
# mean   68.574901   3.795043   9.549407  408.237154  18.455534  356.674032
# std    28.148861   2.105710   8.707259  168.537116   2.164946   91.294864
# min     2.900000   1.129600   1.000000  187.000000  12.600000    0.320000
# max   100.000000  12.126500  24.000000  711.000000  22.000000  396.900000
#
#           lstat       medv
# mean  12.653063  22.532806
# std    7.141062   9.197104
# min    1.730000   5.000000
# max   37.970000  50.000000

# %% [markdown]
# Ok now we have all we need to answer the question.
#
# Do any of the suburbs of Boston appear to have particularly high crime rates?
#
# <span style="color:blue"> Yes, query 1 below shows those that have the highest crime rates. Its interesting the skew in the distribution of the crime rate, as Hist 2 shows that the skew is very far to the left
# </span>

# %%
# Query 1:
Boston.loc[Boston['crim']>=(Boston['crim'].mean()*10)]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666
#
#      ptratio   black  lstat  medv
# 380     20.2  396.90  17.21  10.4
# 398     20.2  396.90  30.59   5.0
# 404     20.2  329.46  27.38   8.5
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0
# 418     20.2   16.45  20.62   8.8
# 427     20.2   18.82  14.52  10.9

# %%
# Hist 2
fig , ax = subplots(figsize=(10, 4))
plt.axvline(Boston['crim'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(Boston['crim'].median(), color='b', linestyle='dashed', linewidth=1)
Boston.hist('crim', color='red', bins=30, ax=ax);

# %%
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
fernando_1 = Boston['tax'].value_counts()

fernando_1[sorted(fernando_1.index, reverse = True)].to_frame()
# Out:
#      count
# tax
# 711      5
# 666    132
# 469      1
# 437     15
# 432      9
# ..     ...
# 216      5
# 198      1
# 193      8
# 188      7
# 187      1
#
# [66 rows x 1 columns]

# %%
# Hist 2
fig , ax = subplots(figsize=(10, 4))
plt.axvline(Boston['crim'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(Boston['crim'].median(), color='b', linestyle='dashed', linewidth=1)
ax.legend()
Boston.hist('crim', color='red', bins=30, ax=ax);
# Out:
# C:\Users\marco.valenzuela\AppData\Local\Temp\ipykernel_27192\3454287310.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
# Hist 2
fig , ax = subplots(figsize=(10, 4))
plt.axvline(Boston['crim'].mean(), color='k', linestyle='dashed', linewidth=1, label="hello")
plt.axvline(Boston['crim'].median(), color='b', linestyle='dashed', linewidth=1, label="world")

Boston.hist('crim', color='red', bins=30, ax=ax, label="bars");

ax.legend()

# %% [markdown]
# (f) How many of the suburbs in this data set bound the Charles
# river?

# %%
Boston.loc[Boston['chas']==1][['chas']].sum()
# Out:
# chas    35
# dtype: int64

# %% [markdown]
# (g) What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
Boston[['ptratio']].median()
# Out:
# ptratio    19.05
# dtype: float64

# %% [markdown]
# (h) Which suburb of Boston has lowest median value of owneroccupied
# homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your findings.

# %%
Boston[['medv']].min()
# Out:
# medv    5.0
# dtype: float64

# %%
Boston.sort_values(by = ["medv"], ascending = True).head(3)
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 400  25.0461  0.0   18.1     0  0.693  5.987  100.0  1.5888   24  666
#
#      ptratio   black  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0
# 400     20.2  396.90  26.77   5.6

# %%
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Mean crim in both of these (398 and 405) as much higher
# Proportion of residential land zoned for lots over 25k sq ft. is much lower (its 0)
# Indus is higher, but within 1 std deviation
# "rm" rm is lower, but within 2 std devs so nothing crazy
# "age" is higher but within 2 std devs
# "dis" is lower, but within 2 std devs
# "rad" is higher, but within 2 std devs
# "tax" is within 2 quartiles for both, and one of the most common results (iirc it is the median)
# "ptratio" is within 2 std devs
# "black" is within 1 std dev
# "lstat" is higher, over 2 std devs higher
#
# and of course, "medv" is lower, below 2 std devs below

# %% [markdown]
# (i) In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling.

# %%
Boston.loc[Boston['rm']>7].count()
# Out:
# crim       64
# zn         64
# indus      64
# chas       64
# nox        64
# rm         64
# age        64
# dis        64
# rad        64
# tax        64
# ptratio    64
# black      64
# lstat      64
# medv       64
# dtype: int64
